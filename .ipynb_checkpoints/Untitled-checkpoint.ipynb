# %%
import pandas as pd

data = pd.read_csv('./data.csv')

colleges = data['Allotted Institute'].unique()


def get_open_close(d):
  if len(d) == 0:
    return "NA","NA"
  return d[0], d[-1]

def open_close(cd):
  info = {}
  categories = cd['Alloted Category'].unique()
  for category in categories:
    cat_data = cd[cd['Alloted Category'] == category]
    o, c = get_open_close(cat_data['Rank'].values)
    info[category] = {
        "total": len(cat_data),
        "opening": o,
        "closing": c,
    }
  return info

op_data = {}
for college in colleges:
  college_data = data[data['Allotted Institute'] == college]
  info = open_close(college_data)
  op_data[college] = info

def get_oc(col):
  return op_data[col]

# %%
from flask import Flask, request, render_template
import pandas as pd
from flask_wtf import FlaskForm
from wtforms import SelectField 
import numpy as np

data = pd.read_csv('./data.csv')
data2 = pd.read_csv('./data2.csv')
data2 = data2[data2['Admitted Round'] == 2]

colleges = data['Allotted Institute'].unique()
colleges = np.sort(np.array(colleges))

colleges2 = data2['Institute'].unique()
colleges2 = np.sort(np.array(colleges2))
colleges2 = [c.replace('\n',"") for c in colleges2]

def get_open_close(d):
  if len(d) == 0:
    return "NA","NA"
  return d[0], d[-1]

def open_close(cd):
  info = {}
  categories = cd['Alloted Category'].unique()
  for category in categories:
    cat_data = cd[cd['Alloted Category'] == category]
    o, c = get_open_close(cat_data['Rank'].values)
    info[category] = {
        "total": len(cat_data),
        "opening": o,
        "closing": c,
    }
  return info

def open_close2(cd):
  info = {}
  categories = cd['Allotted Category'].unique()
  for category in categories:
    cat_data = cd[cd['Allotted Category'] == category]
    o, c = get_open_close(cat_data['AIR'].values)
    info[category] = {
        "total": len(cat_data),
        "opening": o,
        "closing": c,
    }
  return info

op_data = {}
for college in colleges:
  college_data = data[data['Allotted Institute'] == college]
  info = open_close(college_data)
  op_data[college] = info

op_data2 = {}
for college in colleges2:
  college_data = data2[data2['Institute'] == college]
  op_data2[college] = open_close2(college_data)

def get_oc(col):
  return op_data[col]

def get_oc2(col):
  return op_data2[col]

cols2 = [k for k in op_data2]
cols2 = np.sort(np.array(cols2))

app = Flask(__name__)
app.config['SECRET_KEY'] = 'any secret string'

class Form(FlaskForm):
	college = SelectField("college", choices = colleges)

class Form2(FlaskForm):
	college = SelectField("college", choices = cols2)

# %%
op_data2
# Out:
# {'AB Shetty Memorial Inst. of DentalSce., Mangaluru': {},
#  'ACS Medical College and Hospital,Chennai': {},
#  'ACSR Govt Medical College, Nellore': {'OP': {'total': 6,
#    'opening': 11698,
#    'closing': 13480},
#   'SC': {'total': 2, 'opening': 64655, 'closing': 70449}},
#  'AGARTALA GOVT. MEDICALCOLLEGE,AGARTALA': {},
#  'AIIMS Bathinda': {'OP': {'total': 9, 'opening': 1234, 'closing': 3238},
#   'OBC': {'total': 9, 'opening': 3304, 'closing': 5247},
#   'EW': {'total': 5, 'opening': 4068, 'closing': 4759},
#   'SC': {'total': 3, 'opening': 18014, 'closing': 640691},
#   'ST': {'total': 2, 'opening': 32974, 'closing': 42654}},
#  'AIIMS Bilaspur Changar Palasiyan,Himachal Pradesh': {},
#  'AIIMS Guahawti': {'OP': {'total': 9, 'opening': 2480, 'closing': 229488},
#   'OBC': {'total': 2, 'opening': 7982, 'closing': 8094},
#   'EW': {'total': 2, 'opening': 8066, 'closing': 8893},
#   'SC': {'total': 2, 'opening': 47514, 'closing': 47763}},
#  'AIIMS Jammu': {'OP': {'total': 9, 'opening': 4043, 'closing': 7575},
#   'EW': {'total': 4, 'opening': 7916, 'closing': 9308},
#   'OBC': {'total': 6, 'opening': 7994, 'closing': 444583},
#   'SC': {'total': 3, 'opening': 38197, 'closing': 45798}},
#  'AIIMS Mangalagiri': {'OP': {'total': 13, 'opening': 1052, 'closing': 3769},
#   'SC': {'total': 3, 'opening': 4342, 'closing': 28443},
#   'OBC': {'total': 15, 'opening': 4372, 'closing': 465525},
#   'EW': {'total': 4, 'opening': 5033, 'closing': 6218},
#   'ST': {'total': 1, 'opening': 16114, 'closing': 16114}},
#  'AIIMS Rajkot': {'OP': {'total': 10, 'opening': 3094, 'closing': 405987},
#   'EW': {'total': 3, 'opening': 5514, 'closing': 6284},
#   'OBC': {'total': 5, 'opening': 5640, 'closing': 6867},
#   'SC': {'total': 1, 'opening': 29372, 'closing': 29372},
#   'ST': {'total': 2, 'opening': 47640, 'closing': 53178}},
#  'AIIMS Telangana  Bibi Nagar  Village Rangapur Mandal Name Bibinagar': {'OP': {'total': 9,
#    'opening': 1645,
#    'closing': 3895},
#   'EW': {'total': 3, 'opening': 4922, 'closing': 6498},
#   'OBC': {'total': 6, 'opening': 4985, 'closing': 6073},
#   'SC': {'total': 3, 'opening': 33428, 'closing': 679877}},
#  'AIIMS, Bhubaneswar': {'OP': {'total': 3, 'opening': 524, 'closing': 164111},
#   'OBC': {'total': 5, 'opening': 1206, 'closing': 249589},
#   'EW': {'total': 1, 'opening': 2196, 'closing': 2196},
#   'SC': {'total': 1, 'opening': 6592, 'closing': 6592},
#   'ST': {'total': 2, 'opening': 22072, 'closing': 26145}},
#  'AIIMS, Deogarh': {'OP': {'total': 11, 'opening': 5692, 'closing': 212817},
#   'OBC': {'total': 4, 'opening': 6912, 'closing': 7630},
#   'EW': {'total': 3, 'opening': 7156, 'closing': 7637},
#   'SC': {'total': 2, 'opening': 29774, 'closing': 46710},
#   'ST': {'total': 1, 'opening': 59401, 'closing': 59401}},
#  'AIIMS, Gorakhpur': {'OP': {'total': 25, 'opening': 2204, 'closing': 5005},
#   'OBC': {'total': 14, 'opening': 5141, 'closing': 6584},
#   'EW': {'total': 2, 'opening': 5733, 'closing': 5804},
#   'SC': {'total': 8, 'opening': 29101, 'closing': 477699},
#   'ST': {'total': 3, 'opening': 52826, 'closing': 58616}},
#  'AIIMS, Jodhpur': {'OP': {'total': 4, 'opening': 363, 'closing': 790},
#   'OBC': {'total': 6, 'opening': 1034, 'closing': 175670},
#   'EW': {'total': 2, 'opening': 1744, 'closing': 1763},
#   'SC': {'total': 5, 'opening': 3373, 'closing': 13807},
#   'ST': {'total': 2, 'opening': 13143, 'closing': 19774}},
#  'AIIMS, Kalyani': {'OP': {'total': 24, 'opening': 2675, 'closing': 339301},
#   'OBC': {'total': 21, 'opening': 6186, 'closing': 346885},
#   'EW': {'total': 8, 'opening': 6192, 'closing': 7114},
#   'SC': {'total': 3, 'opening': 28656, 'closing': 41733},
#   'ST': {'total': 2, 'opening': 47873, 'closing': 62522}},
#  'AIIMS, Nagpur': {'OP': {'total': 16, 'opening': 1729, 'closing': 2627},
#   'OBC': {'total': 17, 'opening': 2642, 'closing': 278934},
#   'EW': {'total': 3, 'opening': 3736, 'closing': 3928},
#   'SC': {'total': 5, 'opening': 21783, 'closing': 23128},
#   'ST': {'total': 2, 'opening': 40654, 'closing': 40670}},
#  'AIIMS, New Delhi': {'OBC': {'total': 2, 'opening': 24804, 'closing': 50305}},
#  'AIIMS, Patna': {'OP': {'total': 14, 'opening': 940, 'closing': 1984},
#   'OBC': {'total': 15, 'opening': 2722, 'closing': 3122},
#   'EW': {'total': 5, 'opening': 2749, 'closing': 218586},
#   'SC': {'total': 6, 'opening': 18466, 'closing': 26036},
#   'ST': {'total': 3, 'opening': 35942, 'closing': 40497}},
#  'AIIMS, Rai Bareli': {'OP': {'total': 16, 'opening': 3941, 'closing': 292121},
#   'OBC': {'total': 12, 'opening': 5374, 'closing': 6350},
#   'EW': {'total': 6, 'opening': 5524, 'closing': 6280},
#   'SC': {'total': 6, 'opening': 24863, 'closing': 603011},
#   'ST': {'total': 3, 'opening': 42849, 'closing': 500187}},
#  'AIIMS, Raipur': {'OP': {'total': 11, 'opening': 946, 'closing': 267752},
#   'OBC': {'total': 12, 'opening': 2029, 'closing': 2729},
#   'EW': {'total': 5, 'opening': 3312, 'closing': 3611},
#   'SC': {'total': 4, 'opening': 11138, 'closing': 15351},
#   'ST': {'total': 3, 'opening': 33744, 'closing': 38976}},
#  'AIIMS, Rishikesh': {'OP': {'total': 15, 'opening': 765, 'closing': 1366},
#   'OBC': {'total': 10, 'opening': 1739, 'closing': 2171},
#   'EW': {'total': 4, 'opening': 1825, 'closing': 2521},
#   'SC': {'total': 7, 'opening': 11675, 'closing': 20292},
#   'ST': {'total': 4, 'opening': 27037, 'closing': 31908}},
#  'AIIMS-Bhopal,': {'OP': {'total': 9, 'opening': 188, 'closing': 614},
#   'OBC': {'total': 7, 'opening': 1461, 'closing': 1636},
#   'SC': {'total': 2, 'opening': 13243, 'closing': 14209},
#   'ST': {'total': 1, 'opening': 18784, 'closing': 18784}},
#  'ANUGRAH NARAYAN MAGADHMEDICAL COLLEGE, GAYA': {},
#  'ASSAM MEDICAL COLLEGE,DIBRUGARH': {},
#  'ATAL BIHARI VAJPAYEEGOVERNMENT MEDICAL COLLEGE, VIDISHA': {},
#  'ATAL BIHARI VAJPAYEE GOVERNMENT MEDICAL COLLEGE,VIDISHA': {},
#  'Aarupadai Veedu Medical College andHospt., Puducherry': {},
#  'Amrita Institute of Medical Science,Kochi': {},
#  'Amrita School of Dentistry, Kochi': {'OP': {'total': 12,
#    'opening': 170263,
#    'closing': 668131}},
#  'Andaman and Nicobar IslandsInstitute of Medical S': {},
#  'Andhra Medical College,Visakhapatnam': {},
#  'Atal Bihari Vajpayee Institute ofMedical Sciences, New Delhi': {},
#  'B.J. MEDICAL COLLEGE, AHMEDABAD': {'OP': {'total': 4,
#    'opening': 130,
#    'closing': 976},
#   'ST': {'total': 2, 'opening': 40414, 'closing': 47882}},
#  'B.L.D.E University, Bijapur': {'OP': {'total': 73,
#    'opening': 127228,
#    'closing': 554308}},
#  'B.R.D. MEDICAL COLLEGE,GORAKHPUR': {},
#  'BAHIRAMJEE JIJIBHAI MEDICALCOLLGE, PUNE': {},
#  'BANGALORE MED.COLLEGE,BANGALORE': {},
#  'BANKURA SAMMILANI MEDCOLL,BANKURA': {},
#  'BELGAUM INST. OF MEDICAL SCI.,BELGAUM': {},
#  'BHAARATH MEDICAL COLLEGE ANDHOSPITAL': {},
#  'BIDAR INSTITUTE OF MEDICAL SCI.,BIDAR': {},
#  'BPS Govt. Med. College, Sonepat': {'OP': {'total': 3,
#    'opening': 10730,
#    'closing': 10796},
#   'SC': {'total': 2, 'opening': 55891, 'closing': 59264},
#   'ST': {'total': 1, 'opening': 76907, 'closing': 76907}},
#  'BUNDELKHAND MEDICAL COLLEGE,SAGAR': {},
#  'BURDWAN MEDICALCOLLEGE,BURDWAN': {},
#  'BV Deemed Uni. Med. College andHos., Sangli': {},
#  'BVDU Dental College and Hospital,Navi Mumbai': {},
#  'BVDU Dental College and Hospital,Sangli': {},
#  'Bharati Vidyapeeth DU Dental Collegeand Hospt., Pune': {},
#  'Bharati Vidyapeeth DU MedicalCollege': {},
#  'Bowring lady Curzon Medical CollegeReserch Institute': {},
#  'C. Institute of Medical Sciences,Chamarajanagar': {},
#  'CALCUTTA NATIONAL MEDCOLL,KOLKATA': {},
#  'CHENGALPATTU MEDICALCOLL,CHENGALPATTU': {},
#  'CHHATTISGARH INSTITUTE OFMEDICAL SCIENCES, BILASP': {},
#  'COIMBATORE MEDICALCOLLEGE,COIMBATORE': {},
#  'Chettinad Hos. and Res. Inst.,Kancheepuram': {},
#  'Chhindwara Institute of MedicalSciences': {},
#  'College of Medicine and JNM Hospital': {'OP': {'total': 7,
#    'opening': 10600,
#    'closing': 472655},
#   'SC': {'total': 2, 'opening': 70601, 'closing': 71109}},
#  'DATTA MEGHE MEDICAL COLLEGEWANADONGRI HINGNA NAGPUR': {},
#  'DC, RIMS, Imphal': {'ST': {'total': 1,
#    'opening': 118034,
#    'closing': 118034}},
#  'DR RML HOSPITAL, NEW DELHI': {'EW': {'total': 1,
#    'opening': 907,
#    'closing': 907},
#   'ST': {'total': 1, 'opening': 27822, 'closing': 27822},
#   'OP': {'total': 1, 'opening': 123678, 'closing': 123678}},
#  'DR. VAISHAMPAYAM MEMORIALM.C.,SHOLAPUR': {},
#  'DR.RAJENDRA PRASAD MC, TANDA': {'OP': {'total': 5,
#    'opening': 5722,
#    'closing': 6524},
#   'SC': {'total': 1, 'opening': 45878, 'closing': 45878}},
#  'DR.S.C.GOVT MEDICALCOLLEGE,,NANDED': {},
#  'DR.S.N. MEDICAL COLLEGE, JODHPUR': {'OP': {'total': 13,
#    'opening': 2422,
#    'closing': 379295},
#   'SC': {'total': 1, 'opening': 37548, 'closing': 37548},
#   'ST': {'total': 1, 'opening': 51804, 'closing': 51804}},
#  'DR.Z.A.D.C.,FAC.OFMEDICINE,ALIGARH': {},
#  'Darbhanga Medical College,Laheriasarai': {},
#  'Diamond Harbour Govt MedicalCollege': {},
#  'Dr Ram Manohar Lohia Inst. of Med.Sce., Lucknow': {},
#  'Dr. B.S.A. Medical College, Delhi': {'OP': {'total': 2,
#    'opening': 462,
#    'closing': 477},
#   'SC': {'total': 2, 'opening': 19262, 'closing': 22673},
#   'ST': {'total': 1, 'opening': 31526, 'closing': 31526}},
#  'Dr. DY Patil Dental College and Hosp.Navi Mumbai': {},
#  'Dr. DY Patil Dental College and Hosp.Pune': {},
#  'Dr. DY Patil Medical College andHospt., Pune': {},
#  'Dr. DY Patil Medical College, NaviMumbai': {},
#  'Dr. DYP Edu. Soc. Deemed Uni.,Kolhapur': {},
#  'Dr. R. N. Cooper General Hospital,Juhu, Mumbai': {},
#  'Dr. YS Parmar Govt. Medical College,Nahan': {},
#  'ESI-MC&PGIMS&R, Banglore': {'OP': {'total': 6,
#    'opening': 7690,
#    'closing': 231720},
#   'EW': {'total': 1, 'opening': 9619, 'closing': 9619},
#   'OBC': {'total': 2, 'opening': 9935, 'closing': 10086}},
#  'ESI-PGIMSR, Chennai, TN': {'OP': {'total': 4,
#    'opening': 9017,
#    'closing': 530161},
#   'OBC': {'total': 4, 'opening': 10682, 'closing': 11754},
#   'EW': {'total': 2, 'opening': 12121, 'closing': 13075}},
#  'ESIC Dental College and Hospital': {'OP': {'total': 5,
#    'opening': 25025,
#    'closing': 27213},
#   'OBC': {'total': 5, 'opening': 32863, 'closing': 40884},
#   'EW': {'total': 2, 'opening': 36192, 'closing': 36663},
#   'SC': {'total': 2, 'opening': 92490, 'closing': 105843},
#   'ST': {'total': 1, 'opening': 189646, 'closing': 189646}},
#  'ESIC Dental College, Gulbarga': {'OP': {'total': 3,
#    'opening': 51373,
#    'closing': 54594},
#   'OBC': {'total': 5, 'opening': 63834, 'closing': 71447},
#   'EW': {'total': 1, 'opening': 81672, 'closing': 81672},
#   'SC': {'total': 3, 'opening': 252643, 'closing': 265447}},
#  'ESIC MC, Gulbarga, Karnataka': {'OP': {'total': 2,
#    'opening': 10756,
#    'closing': 12026},
#   'OBC': {'total': 2, 'opening': 12587, 'closing': 12822},
#   'EW': {'total': 1, 'opening': 12798, 'closing': 12798},
#   'SC': {'total': 1, 'opening': 71231, 'closing': 71231},
#   'ST': {'total': 1, 'opening': 85385, 'closing': 85385}},
#  'ESIC Medical College AND PGIMSR,Bangalore': {},
#  'ESIC Medical College AND PGIMSR,Chennai': {},
#  'ESIC Medical College AND PGIMSR,Kolkata': {},
#  'ESIC Medical College, Faridabad': {'OP': {'total': 16,
#    'opening': 6414,
#    'closing': 19017},
#   'OBC': {'total': 11, 'opening': 19113, 'closing': 34963},
#   'EW': {'total': 3, 'opening': 19865, 'closing': 21088},
#   'SC': {'total': 7, 'opening': 88307, 'closing': 132740},
#   'ST': {'total': 2, 'opening': 136544, 'closing': 227224}},
#  'ESIC Medical College, Gulbarga': {'OP': {'total': 21,
#    'opening': 31614,
#    'closing': 44546},
#   'OBC': {'total': 15, 'opening': 44735, 'closing': 50646},
#   'EW': {'total': 5, 'opening': 50559, 'closing': 52555},
#   'SC': {'total': 8, 'opening': 170414, 'closing': 208311},
#   'ST': {'total': 1, 'opening': 670720, 'closing': 670720}},
#  'ESIC Medical College, Hyderabad': {'OP': {'total': 3,
#    'opening': 6636,
#    'closing': 8575},
#   'EW': {'total': 1, 'opening': 10489, 'closing': 10489},
#   'SC': {'total': 2, 'opening': 54889, 'closing': 491624}},
#  'ESIC Medical College, Hyderbad': {'OP': {'total': 16,
#    'opening': 27007,
#    'closing': 35951},
#   'OBC': {'total': 10, 'opening': 38166, 'closing': 43773},
#   'EW': {'total': 5, 'opening': 38235, 'closing': 46093},
#   'SC': {'total': 6, 'opening': 93896, 'closing': 154847},
#   'ST': {'total': 3, 'opening': 127594, 'closing': 220578}},
#  'ESIC PGIMSR, Joka, Kolkata, WB': {'OP': {'total': 2,
#    'opening': 9328,
#    'closing': 9849},
#   'OBC': {'total': 1, 'opening': 10498, 'closing': 10498},
#   'EW': {'total': 1, 'opening': 11881, 'closing': 11881},
#   'ST': {'total': 2, 'opening': 80954, 'closing': 82806}},
#  'Employees State InsuranceCorporation Medical Collage': {},
#  'FACULTY OF DEN SCI, KG MEDUNIV,LUCKNOW': {},
#  'Faculty of Dentistry, Jamia MilliaIslamia, New Delhi': {},
#  'Fakhruddin Ali Ahmed MedicalCollege, Barpeta': {},
#  'G.R. MEDICAL COLLEGE, GWALIOR': {'OP': {'total': 13,
#    'opening': 6211,
#    'closing': 518996},
#   'SC': {'total': 2, 'opening': 55125, 'closing': 56311},
#   'ST': {'total': 1, 'opening': 65028, 'closing': 65028}},
#  'G.S.V.M. MEDICAL COLLEGE, KANPUR': {'OP': {'total': 14,
#    'opening': 3341,
#    'closing': 6440},
#   'SC': {'total': 3, 'opening': 37600, 'closing': 50901},
#   'ST': {'total': 2, 'opening': 58269, 'closing': 68868}},
#  'GANDHI MEDICAL COLLEGE, BHOPAL': {'OP': {'total': 6,
#    'opening': 2531,
#    'closing': 130932},
#   'SC': {'total': 1, 'opening': 54494, 'closing': 54494},
#   'ST': {'total': 1, 'opening': 59900, 'closing': 59900}},
#  'GDC,PT.BDS UNIV.OF HEALTHSCI,ROHTAK': {},
#  'GHARWALE GOVT.MED SCI&RESEARCH,SRINAGAR': {},
#  'GITAM Institue of Med. Sce. and Res.,Visakhapatnam': {},
#  'GMC, Azamgarh, UP': {'OP': {'total': 6, 'opening': 11274, 'closing': 11670},
#   'SC': {'total': 1, 'opening': 62052, 'closing': 62052},
#   'ST': {'total': 1, 'opening': 76826, 'closing': 76826}},
#  'GMC, Manjeri, Kerala': {'OP': {'total': 10,
#    'opening': 5518,
#    'closing': 344859},
#   'SC': {'total': 1, 'opening': 77606, 'closing': 77606}},
#  'GMC, Shahjhanpur': {'OP': {'total': 6, 'opening': 11867, 'closing': 12968},
#   'SC': {'total': 3, 'opening': 60947, 'closing': 66678},
#   'ST': {'total': 1, 'opening': 79152, 'closing': 79152}},
#  'GOA MEDICAL COLLEGE, PANAJI': {'OP': {'total': 12,
#    'opening': 7295,
#    'closing': 9828},
#   'SC': {'total': 2, 'opening': 55402, 'closing': 59578}},
#  'GOVERMENT MEDICAL COLLEGENANDURBAR MAHARARASTRA': {},
#  'GOVERNMENT MEDICAL COLLEGEAND HOSPITAL, CHANDIGAR': {},
#  'GOVERNMENT MEDICAL COLLEGE,AKOLA': {},
#  'GOVERNMENT MEDICAL COLLEGE,LATUR': {},
#  'GOVERNMENT MEDICAL COLLEGE,MIRAJ': {},
#  'GOVERNMENT MEDICAL COLLEGE,SURAT': {},
#  'GOVT MEDICAL COLLEGE,ANANTAPURAMU': {},
#  'GOVT. COLLEGE OF DENTISTRY,INDORE': {},
#  'GOVT. D.C. & RESEARCHINST,BANGALORE': {},
#  'GOVT. DC & RESEARCH INSt., BELLARY': {'OP': {'total': 1,
#    'opening': 22728,
#    'closing': 22728}},
#  'GOVT. DENTAL COLL.& HOSP.,JAMNAGAR': {},
#  'GOVT. DENTAL COLLEGE &HOSP,AHMEDABAD': {},
#  'GOVT. DENTAL COLLEGE &HOSP.,AURANGABAD': {},
#  'GOVT. DENTAL COLLEGE &HOSP.,NAGPUR': {},
#  'GOVT. DENTAL COLLEGE,TRIVANDRUM': {},
#  'GOVT. DENTAL COLLEGE, KOZIKODE': {'OP': {'total': 3,
#    'opening': 19535,
#    'closing': 22241}},
#  'GOVT. DENTAL COLLEGE, RAIPUR': {'OP': {'total': 3,
#    'opening': 21590,
#    'closing': 25990},
#   'ST': {'total': 1, 'opening': 131543, 'closing': 131543}},
#  'GOVT. DHARAMAPURI MEDCOLL,DHARMAPURI': {},
#  'GOVT. KILPAUK MEDICALCOLLEGE,CHENNAI': {},
#  'GOVT. MEDICALCOLLEGE,AURANGABAD': {},
#  'GOVT. MEDICALCOLLEGE,TIRUNELVELI': {},
#  'GOVT. MEDICAL COLLEGE,KOTTAYAM': {},
#  'GOVT. MEDICAL COLLEGE,KOZHIKODE': {},
#  'GOVT. MEDICAL COLLEGE, NAGPUR': {'OP': {'total': 11,
#    'opening': 5559,
#    'closing': 434683},
#   'SC': {'total': 2, 'opening': 20211, 'closing': 26861},
#   'ST': {'total': 3, 'opening': 68190, 'closing': 71835}},
#  'GOVT. MEDICAL COLLEGE,PATIALA': {'OP': {'total': 9,
#    'opening': 4680,
#    'closing': 6605},
#   'SC': {'total': 1, 'opening': 32740, 'closing': 32740},
#   'ST': {'total': 2, 'opening': 74693, 'closing': 77486}},
#  'GOVT. MOHAN KUMARAMANGALAM M.C.,SALEM': {'OP': {'total': 10,
#    'opening': 7270,
#    'closing': 7989},
#   'ST': {'total': 1, 'opening': 94786, 'closing': 94786}},
#  'GOVT. VELLORE MEDICAL COLLEGE,VELLORE': {},
#  'GOVT.MEDICAL COLLEGE, AMRITSAR': {'OP': {'total': 10,
#    'opening': 5414,
#    'closing': 7820},
#   'SC': {'total': 2, 'opening': 43920, 'closing': 52118}},
#  'GOVT.MEDICAL COLLEGE, KOTA': {'OP': {'total': 10,
#    'opening': 3629,
#    'closing': 7802},
#   'SC': {'total': 1, 'opening': 41256, 'closing': 41256},
#   'ST': {'total': 1, 'opening': 41456, 'closing': 41456}},
#  'GOVT.MEDICAL COLLEGE, THRISSUR': {'OP': {'total': 9,
#    'opening': 3602,
#    'closing': 4129},
#   'SC': {'total': 3, 'opening': 64253, 'closing': 66915},
#   'ST': {'total': 1, 'opening': 75444, 'closing': 75444}},
#  'GOVT.MEDICAL COLLEGE,THIRUVANANTHAPURAM': {'OP': {'total': 2,
#    'opening': 1859,
#    'closing': 242440},
#   'SC': {'total': 1, 'opening': 42049, 'closing': 42049},
#   'ST': {'total': 1, 'opening': 66763, 'closing': 66763}},
#  'GRANT MEDICAL COLL & SIRJ.J.HOSP,MUMBAI': {},
#  'GTMC, THIRUVARUR': {'OP': {'total': 9, 'opening': 10085, 'closing': 10748},
#   'SC': {'total': 3, 'opening': 77293, 'closing': 80297},
#   'ST': {'total': 1, 'opening': 96508, 'closing': 96508}},
#  'GUNTUR MEDICAL COLLEGE, GUNTUR': {'OP': {'total': 15,
#    'opening': 7321,
#    'closing': 427275},
#   'SC': {'total': 4, 'opening': 18930, 'closing': 63379}},
#  'GURU GOVIND SINGH MEDCOLL,FARIDKOT': {},
#  'GUWAHATI MEDICAL COLLEGE,GUWAHATI': {},
#  'GVMC, VILLUPURAM': {'OP': {'total': 8, 'opening': 9807, 'closing': 10421},
#   'SC': {'total': 1, 'opening': 72965, 'closing': 72965}},
#  'Gadag Institute of Medical Sciences': {'OP': {'total': 11,
#    'opening': 11390,
#    'closing': 13424},
#   'SC': {'total': 2, 'opening': 78603, 'closing': 78608},
#   'ST': {'total': 1, 'opening': 82524, 'closing': 82524}},
#  'Gandhi Medical College MusheerabadSecunderabad': {},
#  'Gmc, Bahraich': {'OP': {'total': 4, 'opening': 12138, 'closing': 12889},
#   'SC': {'total': 1, 'opening': 66685, 'closing': 66685},
#   'ST': {'total': 1, 'opening': 80614, 'closing': 80614}},
#  'Goverment Medical College AndHospital Jalgaon': {},
#  'Goverment Medical College, Bettiah': {'OP': {'total': 6,
#    'opening': 11321,
#    'closing': 204384},
#   'SC': {'total': 1, 'opening': 67808, 'closing': 67808},
#   'ST': {'total': 1, 'opening': 86438, 'closing': 86438}},
#  'Goverment Medical College, Datia': {'OP': {'total': 8,
#    'opening': 11450,
#    'closing': 13404},
#   'SC': {'total': 3, 'opening': 65805, 'closing': 68062},
#   'ST': {'total': 1, 'opening': 81361, 'closing': 81361}},
#  'Government Dental CollegeHyderabad': {},
#  'Government Doon Medcial College,Dehradun': {},
#  'Government Medcial College,Ambikapur': {},
#  'Government Medcial College, Gondia': {'OP': {'total': 14,
#    'opening': 12267,
#    'closing': 446518},
#   'SC': {'total': 3, 'opening': 72967, 'closing': 74318}},
#  'Government Medical CollegeHamirpur': {},
#  'Government Medical CollegeKhaleelwadi': {},
#  'Government Medical CollegeSuryapet': {},
#  'Government Medical College Siddipet': {'OP': {'total': 16,
#    'opening': 13126,
#    'closing': 522877},
#   'ST': {'total': 1, 'opening': 66731, 'closing': 66731},
#   'SC': {'total': 3, 'opening': 69915, 'closing': 77026}},
#  'Government Medical College andHospital, Balangir': {},
#  'Government Medical College,Bharatpur': {},
#  'Government Medical College,Bhilwara': {},
#  'Government Medical College,Mahabubangar': {},
#  'Government Medical College,Omandurar': {},
#  'Government Medical College,Rajnandgaon': {},
#  'Government Medical College, Banda': {'OP': {'total': 9,
#    'opening': 11861,
#    'closing': 403830},
#   'SC': {'total': 2, 'opening': 66703, 'closing': 66916},
#   'ST': {'total': 1, 'opening': 82652, 'closing': 82652}},
#  'Government Medical College, Kollam': {'OP': {'total': 22,
#    'opening': 5020,
#    'closing': 17056},
#   'OBC': {'total': 9, 'opening': 16286, 'closing': 19895},
#   'EW': {'total': 4, 'opening': 25496, 'closing': 46266},
#   'SC': {'total': 6, 'opening': 154923, 'closing': 187960}},
#  'Government Medical College, Pali': {'OP': {'total': 8,
#    'opening': 9011,
#    'closing': 9941},
#   'SC': {'total': 3, 'opening': 57777, 'closing': 58403},
#   'ST': {'total': 2, 'opening': 68049, 'closing': 68163}},
#  'Government of Medical College andHospital, Balasore': {},
#  'Govt Dental College RIMS Kadapa': {'OP': {'total': 2,
#    'opening': 25680,
#    'closing': 25708}},
#  'Govt Medical College Badaun': {'OP': {'total': 8,
#    'opening': 8690,
#    'closing': 12689},
#   'SC': {'total': 1, 'opening': 62450, 'closing': 62450},
#   'ST': {'total': 1, 'opening': 82572, 'closing': 82572}},
#  'Govt Medical College Baramati': {'OP': {'total': 8,
#    'opening': 11496,
#    'closing': 14273},
#   'SC': {'total': 1, 'opening': 61579, 'closing': 61579}},
#  'Govt Medical College BarmerRajasthan': {},
#  'Govt Medical College Basti': {'OP': {'total': 8,
#    'opening': 11929,
#    'closing': 327728},
#   'SC': {'total': 1, 'opening': 64985, 'closing': 64985}},
#  'Govt Medical College Faizabad': {'OP': {'total': 6,
#    'opening': 11557,
#    'closing': 12982},
#   'SC': {'total': 2, 'opening': 61777, 'closing': 63473},
#   'ST': {'total': 1, 'opening': 85254, 'closing': 85254}},
#  'Govt Medical College Firozabad': {'OP': {'total': 6,
#    'opening': 10977,
#    'closing': 11566},
#   'SC': {'total': 3, 'opening': 62122, 'closing': 685868}},
#  'Govt Medical College Kannur': {'OP': {'total': 8,
#    'opening': 4309,
#    'closing': 5816},
#   'SC': {'total': 1, 'opening': 54319, 'closing': 54319}},
#  'Govt Medical College Nalgonda': {'OP': {'total': 14,
#    'opening': 14127,
#    'closing': 491681},
#   'SC': {'total': 2, 'opening': 80015, 'closing': 80108}},
#  'Govt Medical College Ratlam': {'OP': {'total': 14,
#    'opening': 10719,
#    'closing': 525385},
#   'SC': {'total': 1, 'opening': 62062, 'closing': 62062},
#   'ST': {'total': 2, 'opening': 75092, 'closing': 75592}},
#  'Govt Medical College Shahdol': {'OP': {'total': 5,
#    'opening': 11942,
#    'closing': 13616},
#   'SC': {'total': 1, 'opening': 68408, 'closing': 68408},
#   'ST': {'total': 1, 'opening': 84901, 'closing': 84901}},
#  'Govt Medical College, Churu': {'OP': {'total': 8,
#    'opening': 9475,
#    'closing': 10053},
#   'SC': {'total': 2, 'opening': 58067, 'closing': 58243},
#   'ST': {'total': 1, 'opening': 70534, 'closing': 70534}},
#  'Govt Medical College, Dungarpur': {'OP': {'total': 7,
#    'opening': 10509,
#    'closing': 390045},
#   'ST': {'total': 1, 'opening': 73245, 'closing': 73245}},
#  'Govt Medical College, Ernakulam': {'OP': {'total': 11,
#    'opening': 4290,
#    'closing': 5720},
#   'SC': {'total': 2, 'opening': 74628, 'closing': 75662}},
#  'Govt Medical College, Palakkad': {'OP': {'total': 7,
#    'opening': 6629,
#    'closing': 347150}},
#  'Govt Medical college Shivpuri': {'OP': {'total': 6,
#    'opening': 11163,
#    'closing': 13105},
#   'SC': {'total': 3, 'opening': 60297, 'closing': 68256},
#   'ST': {'total': 1, 'opening': 72299, 'closing': 72299}},
#  'Govt institute of Medcial SciencesKasna': {},
#  'Govt. Med. College and ESIC Hospt.,Coimbatore': {},
#  'Govt. Medical College ESI andHospital, Coimbatore': {},
#  'Govt. Medical College Karur': {'OP': {'total': 12,
#    'opening': 9797,
#    'closing': 11769},
#   'SC': {'total': 3, 'opening': 77182, 'closing': 79963},
#   'ST': {'total': 1, 'opening': 93479, 'closing': 93479}},
#  'Govt. Medical College and  Hospital,Chandrapur': {},
#  'Govt. Medical College, Kannauj': {'OP': {'total': 7,
#    'opening': 9712,
#    'closing': 11226},
#   'SC': {'total': 1, 'opening': 61621, 'closing': 61621},
#   'ST': {'total': 1, 'opening': 75059, 'closing': 75059}},
#  'Govt. Medical College, Khandwa': {'OP': {'total': 12,
#    'opening': 12250,
#    'closing': 505250},
#   'SC': {'total': 2, 'opening': 64464, 'closing': 65251},
#   'ST': {'total': 1, 'opening': 79030, 'closing': 79030}},
#  'Govt. Pudukkottai Medical CollegeHopt., Pudukkott': {},
#  'Govt. Sivgangai M. C. Sivagangai': {'OP': {'total': 8,
#    'opening': 11047,
#    'closing': 11495},
#   'SC': {'total': 2, 'opening': 80243, 'closing': 80389},
#   'ST': {'total': 1, 'opening': 96665, 'closing': 96665}},
#  'Gulbarga Institute of MedicalSciences, Gulbarga': {},
#  'HASSAN INST. MEDICAL SCIENCES,HASSAN': {},
#  'Hamdard Inst. of Med. Sciences andResearch, New Delhi': {},
#  'IMS BHU Dental, Varanasi': {'OP': {'total': 5,
#    'opening': 19439,
#    'closing': 19949},
#   'EW': {'total': 2, 'opening': 20512, 'closing': 21595},
#   'OBC': {'total': 6, 'opening': 22080, 'closing': 664913},
#   'SC': {'total': 1, 'opening': 91307, 'closing': 91307},
#   'ST': {'total': 1, 'opening': 111569, 'closing': 111569}},
#  'INDIRA GANDHI GOVT.MEDICALCOLL., NAGPUR': {},
#  'INDIRA GANDHI MEDICAL COLL.,SHIMLA': {},
#  'INST OF PG MED EDU &RESEARCH,KOLKATA': {},
#  'INST.OF MED.SCIENCES,BHU,VARANASI': {},
#  'IRT Perundurai Medical College,Perundurai': {},
#  'Indira Gandhi Dental College and SBV,Pondycherry': {},
#  'Indira Gandhi Institute of MedicalSciences, Patna': {},
#  'Indira Gandhi Medical College & RI,Puducherry': {},
#  'Institute of Dental Sciences,Bhubaneswar': {},
#  'Institute of Medical Sciences andSUM Host., Bhubaneswar': {},
#  'JAWAHAR LAL NEHRU MEDICAL,AJMER': {},
#  'JHALAWAR MEDICAL COLLEGE,Jhalawar': {},
#  'JIPMER KARAIKAL': {'OP': {'total': 7, 'opening': 1748, 'closing': 2418},
#   'OBC': {'total': 4, 'opening': 2871, 'closing': 3090},
#   'EW': {'total': 2, 'opening': 3011, 'closing': 4101},
#   'SC': {'total': 1, 'opening': 17176, 'closing': 17176},
#   'ST': {'total': 2, 'opening': 21906, 'closing': 28839}},
#  'JIPMER PUDUCHERRY': {'OP': {'total': 3, 'opening': 20143, 'closing': 175},
#   'OBC': {'total': 5, 'opening': 451, 'closing': 505},
#   'EW': {'total': 3, 'opening': 1482, 'closing': 583473},
#   'SC': {'total': 1, 'opening': 4682, 'closing': 4682},
#   'ST': {'total': 1, 'opening': 14465, 'closing': 14465}},
#  'JIPMER, KARAIKAL, INTERNAL': {'OP': {'total': 5,
#    'opening': 34747,
#    'closing': 39568},
#   'OBC': {'total': 3, 'opening': 41783, 'closing': 46708},
#   'SC': {'total': 2, 'opening': 145825, 'closing': 161473},
#   'EW': {'total': 1, 'opening': 287410, 'closing': 287410}},
#  'JIPMER,PUDUCHERRY,INTERNAL': {'OP': {'total': 3,
#    'opening': 18649,
#    'closing': 34442},
#   'OBC': {'total': 3, 'opening': 35298, 'closing': 36896},
#   'EW': {'total': 4, 'opening': 73735, 'closing': 243403},
#   'SC': {'total': 3, 'opening': 85994, 'closing': 139579},
#   'ST': {'total': 3, 'opening': 541319, 'closing': 682716}},
#  'JLN IMS, IMPHAL': {'OP': {'total': 8, 'opening': 14430, 'closing': 14948},
#   'SC': {'total': 1, 'opening': 71832, 'closing': 71832}},
#  'JLN Medical College, Datta Meghe,Wardha': {},
#  'JSS Dental College and Hospital,Jagadguru': {},
#  'JSS Medical College, Jagadguru': {'OP': {'total': 66,
#    'opening': 35646,
#    'closing': 718199}},
#  'JWAHAR LAL NEHRU M.C. AMU,ALIGARH': {},
#  'Jawahar Lal Nehru Medical College,Belagavi': {},
#  'Jawaharlal Nehru Medical College,Bhagalpur': {},
#  'Jorhat Medical College and Hospital,JORHAT': {},
#  'K M Shah Dental Collegel, SumanDeep Vidyapeeth Vadodara': {'OP': {'total': 13,
#    'opening': 209749,
#    'closing': 583808}},
#  'K.A.P. VISWANATHAMG.M.C.,TIRUCHIRAPALLI': {},
#  'K.S Hegde Medical Academy,Mangaluru': {},
#  'KANYAKUMARI GOVT. MED.COLL.,ASARIPALLAM': {},
#  'KARNATAK INST. OF MEDICALSC.,HUBLI': {},
#  'KGMC, LUCKNOW': {'OP': {'total': 7, 'opening': 1084, 'closing': 1800},
#   'SC': {'total': 1, 'opening': 7765, 'closing': 7765},
#   'ST': {'total': 2, 'opening': 35003, 'closing': 38458}},
#  'KLE VK Inst. of Dental Scie. Belagavi': {'OP': {'total': 17,
#    'opening': 180295,
#    'closing': 489483}},
#  'KURNOOL MEDICAL COLLEGE,KURNOOL': {},
#  'Kakatiya Medical College Warangal': {'OP': {'total': 15,
#    'opening': 10258,
#    'closing': 413510},
#   'SC': {'total': 3, 'opening': 65013, 'closing': 67150}},
#  'Kalinga Institute of Dental Sciences,Bhubaneswar': {},
#  'Kalinga Institute of Medical Sciences,Bhubaneswar': {},
#  'Kalpana Chawla Govt. MedicalCollege, Karnal': {},
#  'Karwar Institute of Medical Sciences,Karwar': {},
#  'Kasturba Medical College, ManipalUniv., Mangalore': {},
#  'Kasturba Medical College, ManipalUniv., Manipal': {},
#  'Kodagu Institute of Medical Sciences,Kodagu': {},
#  'Koppal Institute of Medical Sciences': {'OP': {'total': 13,
#    'opening': 12090,
#    'closing': 13537},
#   'SC': {'total': 3, 'opening': 79023, 'closing': 79870},
#   'ST': {'total': 1, 'opening': 82464, 'closing': 82464}},
#  'Krishna Inst. of Med. Scie., Karad': {'OP': {'total': 46,
#    'opening': 131436,
#    'closing': 645328}},
#  'L.L.R.M. MEDICAL COLLEGE, MEERUT': {'OP': {'total': 6,
#    'opening': 5986,
#    'closing': 6963},
#   'SC': {'total': 2, 'opening': 43474, 'closing': 52110},
#   'ST': {'total': 1, 'opening': 70017, 'closing': 70017}},
#  'LADY HARDINGE MEDICAL COLLEGE,NEW DELHI': {},
#  'LOKMANYA TILAK  MUNICIPAL MC,MUMBAI': {},
#  'Lady Hardinge Medical College, NewDelhi': {},
#  'Lt. B R K Government MedicalCollege, Jagdalpur': {},
#  'Lt. L A M Govt. Medical College,Raigarh': {},
#  'M.G.M. MEDICALCOLLEGE,JAMSHEDPUR': {},
#  'M.G.M. MEDICAL COLLEGE, INDORE': {'OP': {'total': 4,
#    'opening': 4444,
#    'closing': 5124},
#   'SC': {'total': 1, 'opening': 46832, 'closing': 46832}},
#  'M.P. SHAH MEDICAL COLLEGE,JAMNAGAR': {},
#  'MADRAS MEDICAL COLLEGE,CHENNAI': {},
#  'MADURAI MEDICAL COLLEGE,MADURAI': {},
#  'MAHARAJA K.C. GAJAPATIM.C.,BRAHMAPUR': {},
#  'MAHARANI LAXMI BAI MEDICALCOLL,JHANSI': {},
#  'MALDA MED. COLLEGE, MALDA': {'OP': {'total': 7,
#    'opening': 12705,
#    'closing': 564115},
#   'SC': {'total': 1, 'opening': 70132, 'closing': 70132},
#   'ST': {'total': 1, 'opening': 89630, 'closing': 89630}},
#  'MANAV RACHNA DENTAL COLLEGEFARIDABAD': {},
#  'MANDYA INST. OF MEDICAL SCI.,MANDYA': {},
#  'MAULANA AZAD INST.OF DENTALSCI,N.DELHI': {},
#  'MAULANA AZAD MEDICAL COLLEGE,NEW DELHI': {},
#  'MEDICAL COLLEGE, BARODA': {'OP': {'total': 9,
#    'opening': 3459,
#    'closing': 4723},
#   'SC': {'total': 2, 'opening': 8289, 'closing': 33937},
#   'ST': {'total': 2, 'opening': 61892, 'closing': 62462}},
#  'MEDICAL COLLEGE, BHAVNAGAR': {'OP': {'total': 13,
#    'opening': 6336,
#    'closing': 8508},
#   'SC': {'total': 2, 'opening': 53809, 'closing': 56154},
#   'ST': {'total': 1, 'opening': 66821, 'closing': 66821}},
#  'MEDICAL COLLEGE, KOLKATA': {'OP': {'total': 4,
#    'opening': 1544,
#    'closing': 2990}},
#  'MG Inst. of Medical Sciences,Sevagram Wardha': {},
#  'MGM Medical College, Aurangabad': {'OP': {'total': 23,
#    'opening': 78366,
#    'closing': 207106}},
#  'MGM Medical College, Navi Mumbai': {'OP': {'total': 24,
#    'opening': 45102,
#    'closing': 621235}},
#  'MIDNAPORE MEDICAL COLLEGE,MIDNAPUR': {},
#  'MM College of Dental Scie. and Res.,Mullana': {},
#  'MM Inst. Med. and Research, Mullana': {'OP': {'total': 51,
#    'opening': 54521,
#    'closing': 230946}},
#  'MOTI LAL NEHRU MEDICAL COLL,ALLAHABAD': {},
#  'MRA MEDICAL COLLEGE AMBEDKARNAGAR, UP': {},
#  'MYSORE MED.& RESEARCH INST.MYSORE': {},
#  'Maharaja Jitendra Narayan Medical College and Hospital Coochbehar': {'OP': {'total': 7,
#    'opening': 12653,
#    'closing': 13985},
#   'SC': {'total': 1, 'opening': 72144, 'closing': 72144},
#   'ST': {'total': 1, 'opening': 93223, 'closing': 93223}},
#  'Mahatma Gandhi Medical College and Sri Balaji Vidyapeeth, Pondicherry': {'OP': {'total': 57,
#    'opening': 79351,
#    'closing': 745651}},
#  'Manipal College of Dental Sce.,Manipal': {},
#  'Manipal College of Dental Science,Mangalore': {},
#  'Manipal Tata Medical College,': {'OP': {'total': 106,
#    'opening': 44800,
#    'closing': 114870}},
#  'Maulana Azad Institute of DentalSciences, New Delhi': {},
#  'Maulana Azad Medical College, NewDelhi': {},
#  'Meenakshi Ammal Dental College andHost., Chennai1': {},
#  'Meenakshi Medical College Host. andRes. Inst., Chennai': {},
#  'Mursidabad M C & Hospital,Mursidabad': {},
#  'NALANDA MEDICAL COLLEGE, PATNA': {'OP': {'total': 5,
#    'opening': 6318,
#    'closing': 8206},
#   'SC': {'total': 2, 'opening': 49193, 'closing': 58661}},
#  'NDMC Medical College, Delhi': {'OP': {'total': 3,
#    'opening': 1567,
#    'closing': 259623},
#   'SC': {'total': 1, 'opening': 21812, 'closing': 21812}},
#  'NEIGRIHMS, SHILLONG': {'OP': {'total': 8,
#    'opening': 9850,
#    'closing': 11839}},
#  'NETAJI SUBHASH CHANDRA BOSEMC,JABALPUR': {},
#  'NILRATAN SIRKAR MEDICAL COLLEGE,KOLKATA': {},
#  'NORTH BENGALDENT.COLL,SUSHRUTNAGAR': {},
#  'NORTH BENGALMED.COLL,DARJEELING': {},
#  'Osmania Medical College Koti': {'OP': {'total': 13,
#    'opening': 2890,
#    'closing': 6051},
#   'SC': {'total': 3, 'opening': 26785, 'closing': 40057},
#   'ST': {'total': 1, 'opening': 38074, 'closing': 38074}},
#  'PATALIPUTRA MEDICAL COLLEGE,DHANBAD': {},
#  'PATNA MEDICAL COLLEGE, PATNA': {'OP': {'total': 12,
#    'opening': 2359,
#    'closing': 201732},
#   'SC': {'total': 2, 'opening': 26151, 'closing': 29963},
#   'ST': {'total': 1, 'opening': 49896, 'closing': 49896}},
#  'PT. B.D. SHARMA PGIMS, ROHTAK': {'OP': {'total': 5,
#    'opening': 3718,
#    'closing': 6617},
#   'SC': {'total': 1, 'opening': 40036, 'closing': 40036}},
#  'Pt. D.D.U MEDICAL COLLEGE, RAJKOT': {'OP': {'total': 5,
#    'opening': 3134,
#    'closing': 4988},
#   'SC': {'total': 1, 'opening': 53612, 'closing': 53612}},
#  'Pt. J N M MEDICAL COLLEGE, RAIPUR': {'OP': {'total': 5,
#    'opening': 8270,
#    'closing': 9756},
#   'ST': {'total': 1, 'opening': 74586, 'closing': 74586},
#   'SC': {'total': 1, 'opening': 588970, 'closing': 588970}},
#  'Pt. Jawahar Lal Nehru Govt. Med.College, Chamba': {},
#  'Pt. Raghunath Murmu Med. College,Baripada': {},
#  'Purulia Government Medical Collegeand Hospital': {},
#  'R.G. KAR MEDICAL COLLEGE,KOLKATA': {'OP': {'total': 14,
#    'opening': 6757,
#    'closing': 8062},
#   'SC': {'total': 4, 'opening': 53065, 'closing': 58652},
#   'ST': {'total': 3, 'opening': 75981, 'closing': 77340}},
#  'R.N.T. MEDICAL COLLEGE, UDAIPUR': {'OP': {'total': 10,
#    'opening': 3826,
#    'closing': 5800},
#   'SC': {'total': 3, 'opening': 45100, 'closing': 46263},
#   'ST': {'total': 1, 'opening': 51449, 'closing': 51449}},
#  'RAICHUR INST. OF MEDICAL SCI.,RAICHUR': {},
#  'RAJENDRA INST. OF MED. SCI.,RANCHI': {},
#  'RAJIV GANDHI INSTITUTE OFMEDICAL SCIENCES, KADAPA': {},
#  'RAJIV GANDHI MEDICAL COLLEGE,THANE': {},
#  'RAMPURHAT GOVT MEDICALCOLLEGE RAMPURHAT': {},
#  'REGIONAL INST OF MEDICAL SCI,IMPHAL': {},
#  'RIMS Srikakulam': {'OP': {'total': 11, 'opening': 12465, 'closing': 14100},
#   'SC': {'total': 3, 'opening': 72536, 'closing': 77208},
#   'ST': {'total': 1, 'opening': 86336, 'closing': 86336}},
#  'RIMS, Ongole': {'OP': {'total': 13, 'opening': 12781, 'closing': 14206},
#   'SC': {'total': 1, 'opening': 78580, 'closing': 78580},
#   'ST': {'total': 1, 'opening': 85418, 'closing': 85418}},
#  'RUHS College of Dental Science,Jaipur': {},
#  'RUHS College of Medical Sciences,Jaipur': {},
#  'Raiganj Government Medical College': {'OP': {'total': 6,
#    'opening': 14412,
#    'closing': 591535},
#   'SC': {'total': 1, 'opening': 73500, 'closing': 73500},
#   'ST': {'total': 1, 'opening': 88349, 'closing': 88349}},
#  'Rajah Muthiah Medical College,Annamalai Universit': {},
#  'Rajarshee Chhatrapati Shahu MaharajGovernment Medical College Kolhapur': {},
#  'Rajarshee Chhatrapati Shahu Maharaj Government Medical CollegeKolhapur': {},
#  'Rajiv Gandhi Institute Medical Sce ofAdilabad': {},
#  'Rajkiya Medical College, Jalaun': {'OP': {'total': 8,
#    'opening': 10481,
#    'closing': 12135},
#   'SC': {'total': 1, 'opening': 62410, 'closing': 62410},
#   'ST': {'total': 1, 'opening': 71901, 'closing': 71901}},
#  'Rangaraya Medical College, Kakinada': {'OP': {'total': 11,
#    'opening': 9840,
#    'closing': 12723},
#   'ST': {'total': 1, 'opening': 56542, 'closing': 56542},
#   'SC': {'total': 1, 'opening': 59263, 'closing': 59263}},
#  'Rural Dental College, Loni': {'OP': {'total': 11,
#    'opening': 261444,
#    'closing': 713328}},
#  'Rural Medical College and PIMS, Loni': {'OP': {'total': 55,
#    'opening': 53964,
#    'closing': 96039}},
#  'S.C.B. MEDICALCOLL(DENTAL),CUTTACK': {},
#  'S.C.B. MEDICAL COLLEGE, CUTTACK': {'OP': {'total': 3,
#    'opening': 2559,
#    'closing': 328733}},
#  'S.M.S. MEDICAL COLLEGE, JAIPUR': {'OP': {'total': 1,
#    'opening': 965,
#    'closing': 965}},
#  'S.N. MEDICAL COLLEGE, AGRA': {'OP': {'total': 6,
#    'opening': 5454,
#    'closing': 7889},
#   'SC': {'total': 1, 'opening': 52919, 'closing': 52919},
#   'ST': {'total': 1, 'opening': 62618, 'closing': 62618}},
#  'S.S. MEDICAL COLLEGE, REWA': {'OP': {'total': 7,
#    'opening': 10107,
#    'closing': 10984},
#   'SC': {'total': 3, 'opening': 59003, 'closing': 62822},
#   'ST': {'total': 1, 'opening': 77507, 'closing': 77507}},
#  'SARDAR PATEL MEDICAL COLLEGE,BIKANER': {},
#  'SATHYABAMA UNIV. Dental Collegeand Hospt. Chennai': {},
#  'SBKS Med. Inst. and Res. Centre,Sumandeep Vidyapeeth': {},
#  'SDU Medical College, Kolar': {'OP': {'total': 62,
#    'opening': 46924,
#    'closing': 556675}},
#  'SETH G.S. MEDICAL COLLEGE,MUMBAI': {},
#  'SH VASANT RAO NAIKGOVT.M.C.,YAVATMAL': {},
#  'SHIMOGA INST. OF MEDICAL SCI.,SHIMOGA': {},
#  'SHKM GMC, Nalhar, Mewat, Haryana': {'OP': {'total': 2,
#    'opening': 11074,
#    'closing': 11118},
#   'SC': {'total': 1, 'opening': 57384, 'closing': 57384}},
#  'SHRI BHAUSAHEB HIRE GOVT. M.C.,DHULE': {},
#  'SHRI KALYAN GOVT MEDICALCOLLEGE SIKAR': {},
#  'SILCHAR MEDICAL COLLEGE, SILCHER': {'OP': {'total': 6,
#    'opening': 13344,
#    'closing': 14369},
#   'SC': {'total': 2, 'opening': 70420, 'closing': 72779},
#   'ST': {'total': 1, 'opening': 89605, 'closing': 89605}},
#  'SLBS Govt. Medical College, Mandi': {'OP': {'total': 14,
#    'opening': 23203,
#    'closing': 41511},
#   'EW': {'total': 4, 'opening': 41810, 'closing': 49219},
#   'OBC': {'total': 9, 'opening': 45303, 'closing': 56442},
#   'SC': {'total': 5, 'opening': 147795, 'closing': 201205},
#   'ST': {'total': 2, 'opening': 289196, 'closing': 434402}},
#  'SRI KRISHNA MEDICAL COLLEGE,MUZAFFARPUR': {},
#  'SRM Dental College, Chennai': {'OP': {'total': 11,
#    'opening': 220487,
#    'closing': 731019}},
#  'SRM Katt. Dental College and Hospt.Chennai': {},
#  'SRM Medical College and Hospital,Chennai': {},
#  'STANLEY MEDICAL COLLEGE,CHENNAI': {},
#  'SUH Maulana Mahmood HasanMedical College, Saharanpur': {},
#  'SVIMS - Sri Padmavathi MedicalCollege for Women, Tirupati': {},
#  'SWAMI RAMANAND TiRTH RURALM.C,AMBAJOGAI': {},
#  'SYMBIOSIS MEDICAL COLLEGE FORWOMEN PUNE': {},
#  'Sagar Dutta Medical College &Hospital, Kolkata': {},
#  'Saheed Laxman Nayak Med. Collegeand Hos., Koraput': {},
#  'Santosh Dental College and Hospital,Ghaziabad': {},
#  'Santosh Medical College and Hospital,Ghaziabad': {},
#  'Saveetha Dental College, Chennai': {'OP': {'total': 22,
#    'opening': 97633,
#    'closing': 780661}},
#  'Saveetha Medical College, Chennai': {'OP': {'total': 35,
#    'opening': 137535,
#    'closing': 709266}},
#  'School of Dental Sciences andKIMSDU, Karad': {},
#  'Sh. Lal Bahadur Shastri Govt. Med.College. Mandi': {},
#  'Sharad Pawar Dental College andHospital, Wardha': {},
#  'Shri Sathya Sai Medical College andRI, Chennai': {},
#  'Shri Vinobha Bhave Institute MedicalSciences': {},
#  'Siddartha Medical College,Vijayawada': {},
#  'Sree Balaji Dental College andHospital, Chennai': {},
#  'Sree Balaji Medical College andHospital, Chennai': {},
#  'Sri Lakshmi Narayana Inst. of Med.Scien., Puducherry': {},
#  'Sri Ramachandra Dental and Hospt.,Chennai': {},
#  'Sri Ramachandra Med. College andRes. Inst., Chennai': {},
#  'Sri Siddhartha Academy T Begur': {'OP': {'total': 73,
#    'opening': 114335,
#    'closing': 278981}},
#  'Sri Siddhartha DentalCollege, Tumkur': {'OP': {'total': 6,
#    'opening': 234951,
#    'closing': 800160}},
#  'Sri Siddhartha Medical College DU,Tumkur': {},
#  'Sri Venkateswara Medical College,Tirupati': {},
#  'T.D. MEDICAL COLLEGE, ALLAPPUZHA': {'OP': {'total': 15,
#    'opening': 4260,
#    'closing': 4697},
#   'SC': {'total': 3, 'opening': 66107, 'closing': 69419},
#   'ST': {'total': 2, 'opening': 87883, 'closing': 93543}},
#  'THANJAVUR MEDICALCOLL.,THANJAVUR': {},
#  'THENI GOVT. MEDICAL COLLEGE,THENI': {},
#  'THOOTHUKUDI MEDICALCOLLEGE,THOOTHUKUDI': {},
#  'TOPIWALA NATIONAL MEDICALCOLLEGE,MUMBAI': {},
#  'Tezpur Medical College, Tezpur': {'OP': {'total': 9,
#    'opening': 13575,
#    'closing': 14930},
#   'SC': {'total': 2, 'opening': 76062, 'closing': 76083},
#   'ST': {'total': 1, 'opening': 95276, 'closing': 95276}},
#  'Thaimoogambigai Dental College andHsopt. Chennai': {},
#  'Thiruvannamalai MC,Thiruvannamalai, TN': {},
#  'Tomo Riba Institute Health andMedical Sciences, Naharlagun': {},
#  'UTTARANCHAL F HOSP TRUSTMC,HALDWANI': {},
#  'University College of MedicalSciences, Delhi': {},
#  'University College of MedicalSciences, New Delhi': {},
#  'Uttar Pradesh University of MedicalSciences, Saifai, Etawah': {},
#  'V.S.S. MEDICAL COLLEGE, BURLA': {'OP': {'total': 6,
#    'opening': 10622,
#    'closing': 13124},
#   'SC': {'total': 1, 'opening': 42969, 'closing': 42969}},
#  'VARDHMAN INSTITUTE OF MEDICALSCIENCES, NALANDA': {},
#  'VIJAYNAGAR INST OF MED.SC,BELLARY': {},
#  'VMKV Medical College and Hospital,Salem': {},
#  'VMMC AND SAFDARJUNG HOSPITAL,NEW DELHI': {},
#  'VMS Dental College, Salem': {'OP': {'total': 8,
#    'opening': 173511,
#    'closing': 380298}},
#  'Vardhman Mahavir Medical Collegeand Safdarjung Hospital New Delhi, VMMC': {},
#  'Vardhman Mahavir Medical College and Safdarjung Hospital New Delhi,VMMC': {},
#  'Vinayaka Missions Medical Collegeand Hospital, Karaikal': {},
#  'Yenepoya Dental College, Yenepoya': {'OP': {'total': 9,
#    'opening': 231800,
#    'closing': 466769}},
#  'Yenepoya Medical College, Mangalore': {'OP': {'total': 41,
#    'opening': 88419,
#    'closing': 564995}},
#  'ZORAM MEDICAL COLLEGE Falkawn': {'OP': {'total': 3,
#    'opening': 14996,
#    'closing': 15023},
#   'SC': {'total': 1, 'opening': 73674, 'closing': 73674}}}

# %%
data2[data2['Institute'] == 'AIIMS, New Delhi']
# Out:
#               Type    AIR Category Sub Category         Institute Subject  \
# 1612  AIIMS  Seats  24804      OBC           PH  AIIMS, New Delhi    MBBS
# 1763  AIIMS  Seats  50305      OBC           PH  AIIMS, New Delhi    MBBS
#
#      Allotted Category Allotted ph  Admitted Round
# 1612               OBC          PH               2
# 1763               OBC          PH               2
